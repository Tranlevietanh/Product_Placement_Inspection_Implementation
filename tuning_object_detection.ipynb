# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")
model.model
# Out:
# ...
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
model = YOLO("yolo11n.pt")
results = model.train(data = "/content/drive/MyDrive/object_detection_tuning/watch_photos_drive/watch_photos_drive_YOLO_customized/data.yaml", epochs = 1, imgsz = 640, patience = 10, batch =  16, save = True, device = 0, optimizer = 'AdamW', freeze = 9, translate = 0.5, scale = 0.5, fliplr = 0, mosaic = 0.3, lr0 = 1e-4, plots = True)
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp -r runs /content/drive/MyDrive

# %%
model_before_tuned = YOLO("yolo11n.pt")
model_after_tuned = YOLO(r"/content/drive/MyDrive/runs/detect/train3/weights/best.pt")

# %%
metrics_before_tuned = model_before_tuned.val(
    data=r"/content/drive/MyDrive/object_detection_tuning/Clock_3/Clock_3_YOLO_original/data_yolo_original.yaml"
)
print (metrics_before_tuned.box.map75)
metrics_after_tuned = model_after_tuned.val(
    data=r"/content/drive/MyDrive/object_detection_tuning/Clock_3/Clock_3_YOLO_customized/data.yaml"
)
print (metrics_after_tuned.box.map75)

# %%
metrics_before_tuned_coco = model_before_tuned.val(
    data=r"/content/drive/MyDrive/object_detection_tuning/watch_photos_drive/watch_photos_drive_YOLO_customized/COCO_val_YOLO_original/data_yolo_original.yaml"
)
print (metrics_before_tuned_coco.box.map75)
metrics_after_tuned_coco = model_after_tuned.val(
    data=r"/content/drive/MyDrive/object_detection_tuning/watch_photos_drive/watch_photos_drive_YOLO_customized/COCO_val/data.yaml"
)
print (metrics_after_tuned_coco.box.map75)

# %%
model_after_tuned.predict("/content/drive/MyDrive/object_detection_tuning/Clock_3/Clock_3_YOLO_customized/images/val", save = True)

# %%
model_after_tuned.predict("/content/drive/MyDrive/object_detection_tuning/watch_photos_drive/watch_photos_drive_YOLO_customized/COCO_val/images", save = True)

# %%
model_after_tuned.predict("/content/drive/MyDrive/object_detection_tuning/watch_photos_drive/watch_photos_drive_YOLO_customized/COCO_no_clock/images", save = True)
