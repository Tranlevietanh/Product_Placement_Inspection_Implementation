# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO(r"/content/drive/MyDrive/slot_runs/runs/detect/train2/weights/best.pt")
results = model.train(data = "/content/drive/MyDrive/slot_detection_copy/slots_drive_YOLO_original/data_config.yaml", epochs = 100, imgsz = 640, patience = 20, batch =  16, save = True, device = 0, pretrained = True, optimizer = 'AdamW', degrees = 90, translate = 0.5, fliplr = 0, flipud = 0, mosaic = 1, plots = True)
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp -r /content/drive/MyDrive/slot_detection/ /content/drive/MyDrive/slot_detection_copy/

# %%
# !cp -r runs /content/drive/MyDrive/slot_runs
